# %%
#install.packages("anytime")
library(anytime)
library(tidyverse)

#loading databases into dataframes
a <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/IBM.csv",stringsAsFactors = FALSE)
b <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/MSFT.csv")
c <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/GOOG.csv")
d <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/AAPL.csv")
e <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/AMZN.csv")
f <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/FB.csv")
g <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/NFLX.csv")
h <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/TSLA.csv")
i <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/ORCL.csv")
j <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/SAP.csv")

#loading databases of YenDollarConversionRate
data.frame <- read.csv("D:/NJIT/Sem 3/Data Analytics/Midterm Project/YenDollar.csv",stringsAsFactors = FALSE)
Yen <- data.frame[c("Date", "Close")]


#loading the specific columns from database 
IBM <- a[,c("Date","Close","Adj.Close")]
MSFT <- b[,c("Close","Adj.Close")]
GOOG <- c[, c("Close","Adj.Close")]
AAPL <- d[, c("Close","Adj.Close")]
AMZN <- e[, c("Close","Adj.Close")]
FB <- f[, c("Close","Adj.Close")]
NFLX <- g[, c("Close","Adj.Close")]
TSLA <- h[, c("Close","Adj.Close")]
ORCL <- i[, c("Close","Adj.Close")]
SAP <- j[, c("Close","Adj.Close")]

#changing column names to relevant names
colnames(IBM)=c('Date', 'IBM Close', 'IBM Adj.Close')
colnames(MSFT)=c( 'MSFT Close', 'MSFT Adj.Close')
colnames(GOOG)=c('GOOG Close', 'GOOG Adj.Close')
colnames(AAPL)=c('AAPL Close', 'AAPL Adj.Close')
colnames(AMZN)=c('AMZN Close', 'AMZN Adj.Close')
colnames(FB)=c('FB Close', 'FB Adj.Close')
colnames(NFLX)=c('NFLX Close', 'NFLX Adj.Close')
colnames(TSLA)=c('TSLA Close', 'TSLA Adj.Close')
colnames(ORCL)=c('ORCL Close', 'ORCL Adj.Close')
colnames(SAP)=c('SAP Close', 'SAP Adj.Close')

StockData <- data.frame(IBM, MSFT, GOOG, AAPL, AMZN, FB, NFLX, TSLA, ORCL, SAP); 
head(StockData)
# Out:
# Installing package into 'C:/Users/srini/OneDrive/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'anytime' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Public\Documents\Wondershare\CreatorTemp\Rtmpy8cvoI\downloaded_packages
# Warning message:
# "package 'anytime' was built under R version 3.6.3"
# Warning message:
# "package 'tidyverse' was built under R version 3.6.3"
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.2.1     v purrr   0.3.3
# v tibble  2.1.3     v dplyr   0.8.4
# v tidyr   1.0.2     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.5.0
#
# Warning message:
# "package 'readr' was built under R version 3.6.3"
# Warning message:
# "package 'forcats' was built under R version 3.6.3"
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#   Date       IBM.Close IBM.Adj.Close MSFT.Close MSFT.Adj.Close GOOG.Close
# 1 2018-01-02 154.25    139.3655      85.95      83.25638       1065.00
# 2 2018-01-03 158.49    143.1963      86.35      83.64384       1082.48
# 3 2018-01-04 161.70    146.0966      87.11      84.38003       1086.40
# 4 2018-01-05 162.49    146.8103      88.19      85.42618       1102.23
# 5 2018-01-08 163.47    147.6958      88.28      85.51336       1106.94
# 6 2018-01-09 163.83    148.0210      88.22      85.45524       1106.26
#   GOOG.Adj.Close AAPL.Close AAPL.Adj.Close AMZN.Close ... FB.Close FB.Adj.Close
# 1 1065.00        172.26     166.8040       1189.01    ... 181.42   181.42
# 2 1082.48        172.23     166.7750       1204.20    ... 184.67   184.67
# 3 1086.40        173.03     167.5496       1209.59    ... 184.33   184.33
# 4 1102.23        175.00     169.4572       1229.14    ... 186.85   186.85
# 5 1106.94        174.35     168.8278       1246.87    ... 188.28   188.28
# 6 1106.26        174.33     168.8085       1252.70    ... 187.87   187.87
#   NFLX.Close NFLX.Adj.Close TSLA.Close TSLA.Adj.Close ORCL.Close ORCL.Adj.Close
# 1 201.07     201.07         320.53     320.53         46.63      44.92264
# 2 205.05     205.05         317.25     317.25         47.71      45.96309
# 3 205.63     205.63         314.62     314.62         48.18      46.41589
# 4 209.99     209.99         316.58     316.58         48.47      46.69527
# 5 212.05     212.05         336.41     336.41         48.98      47.18660
# 6 209.31     209.31         333.69     333.69         49.06      47.44772
#   SAP.Close SAP.Adj.Close
# 1 112.39    109.2076
# 2 113.31    110.1015
# 3 115.05    111.7923
# 4 116.33    113.0360
# 5 114.80    111.5493
# 6 114.16    110.9275

# %%
#Cash= 5million to start investing. Cash always stays in zero interest cash account.
Cash=5000000
#StockValueWeHold = sum of (for each share(NumberOfShare*SharePrice))
StockValue=0
# Mark to Market Value
MTM = Cash + StockValue
#days rebalancing stragegy 
DaysIncrementor =5
#Cash to spend on Each Share
CashEachShare=Cash/DaysIncrementor;

#Shares to Buy, Initial Catalog
BuyCatalog=c("IBM","MSFT","GOOG","AAPL","AMZN")

#dataframe to store Portfolio
Portfolio<-data.frame(matrix(ncol = 4),stringsAsFactors = FALSE)
X <- c("PurchaseDate","Company","Volume","PurchasePrice")
colnames(Portfolio) <- X

#temporary vectors
PurchaseDateT=c();
CompanyT=c();
VolumeT=c();
PurchasePriceT=c();

#initilizer to start row in StockData
Current_Row=1

#temporary vectors for percentage change 
MTMT=c();
MTMPCT=c();

# %%
#function to calculate the percent change
PercentageChange<- function(a,b)
    {
    ((b-a)/a)*100
}

# %%
#function to reset all vairables to default
#you would use it if you want to again run the portfoliorunnerfunction
reset<-function()
    {
    Cash<<-5000000
    StockValue<<-0
    MTM <<- Cash + StockValue
    DaysIncrementor <<-5
    CashEachShare<<-Cash/DaysIncrementor;
    BuyCatalog<<-c("IBM","MSFT","GOOG","AAPL","AMZN")
    Portfolio<<-Portfolio[0,]
    PurchaseDateT<<-c();
    CompanyT<<-c();
    VolumeT<<-c();
    PurchasePriceT<<-c();
    Current_Row <<- 1
    
}

# %%
#Function to update the MTM,Cash, StockValue
updateMTM<-function()
    {
    TotalShareValue=0
    for(i in 1:length(Portfolio$PurchaseDate))
        {
        TotalShareValue=TotalShareValue+Portfolio$Volume[i]*Portfolio$PurchasePrice[i]
    }
    StockValue<<-TotalShareValue
    Cash<<-Cash-TotalShareValue
    MTM<<-StockValue+Cash
}

# %%
#Function to update Portfolio and add all the new bought shares into portfolio
updatePortfolio<-function()
    {
    Portfolio<<-cbind.data.frame(PurchaseDate=PurchaseDateT,Company=CompanyT,Volume=VolumeT,PurchasePrice=PurchasePriceT,stringsAsFactors = FALSE)
    
}

# %%
#Function to output the number of share you can buy on specific date, cash and share name as parameter

QuantityYouGet <- function(DateToBuy,CashToBuy,ShareName,i){
    #Joining ShareName+".Close" so as ColumnName can refer in dataframe StockData 
    ColumnName=paste0(ShareName,".Close")
    
    ShareClosingPrice= StockData[StockData$Date == DateToBuy,ColumnName ]
    
    #floor value of the (cash/price)
    NumberOfShares=floor(CashToBuy/ShareClosingPrice)
    
    PurchaseDateT[i]<<-DateToBuy;
    CompanyT[i]<<-ShareName;
    VolumeT[i]<<-NumberOfShares;
    PurchasePriceT[i]<<-ShareClosingPrice;
    
    #Portfolio<<- rbind(Portfolio,c(DateToBuy,ShareName,NumberOfShares,ShareClosingPrice))
}

# %%
#Function to buy the shares in vector BuyCatalog
buy<-function(DateToBuy)
    {
    for(i in 1:length(BuyCatalog))
        {
            (QuantityYouGet(DateToBuy,CashEachShare,BuyCatalog[i],i))
        }
    updatePortfolio()
    updateMTM()
}

# %%
#Function to caluculate the percentage drop of AdjClose Price
PerAdjCloseDrop<-function(D1,D2,column_name){  
    x1=StockData[StockData$Date == D1 ,c(column_name)]
    x2=StockData[StockData$Date == D2 ,c(column_name)]
    ((x2-x1)/x1)*100
}

# %%
#Function to Update The BuyCatalog as per strategy of rebalancing of buying high or buying low
UpdateBuyCatalog<-function(Current_Row,BuyStrategy,DaysIncrementor)
    {
    Current_Date=StockData$Date[Current_Row]
    Last_Date=StockData$Date[Current_Row-DaysIncrementor]
    share = c("IBM", "MSFT", "GOOG", "AAPL", "AMZN", "FB", "NFLX", "TSLA", "ORCL", "SAP");
    percent = c(PerAdjCloseDrop(Last_Date,Current_Date, "IBM.Adj.Close"),PerAdjCloseDrop(Last_Date,Current_Date, "MSFT.Adj.Close"),PerAdjCloseDrop(Last_Date,Current_Date, "GOOG.Adj.Close"),PerAdjCloseDrop(Last_Date,Current_Date, "AAPL.Adj.Close"),PerAdjCloseDrop(Last_Date,Current_Date, "AMZN.Adj.Close"),PerAdjCloseDrop(Last_Date,Current_Date, "FB.Adj.Close"),PerAdjCloseDrop(Last_Date,Current_Date, "NFLX.Adj.Close"),PerAdjCloseDrop(Last_Date,Current_Date, "TSLA.Adj.Close"),PerAdjCloseDrop(Last_Date,Current_Date, "ORCL.Adj.Close"),PerAdjCloseDrop(Last_Date,Current_Date, "SAP.Adj.Close"))
    DF <- data.frame(share, percent,stringsAsFactors = FALSE) 
    if(BuyStrategy=="buying_low")
        {
        DF <- DF[order(DF$percent),]
    }
    else
        {
        DF <- DF[order(DF$percent,decreasing = TRUE),]
    }
    BuyCatalog<<-DF$share[1:5]
}

# %%
#Function to sell all the shares in the portfolio and update the MTM,Cash, StockValue
SellAllShares<-function(Current_Row)
    {
    Current_Date=StockData$Date[Current_Row]
    
    TotalShareValue=0
    for(i in 1:length(Portfolio$PurchaseDate))
        {
        curr_column = paste0(Portfolio$Company[i], ".Close")
        Current_Price= StockData[StockData$Date==Current_Date, curr_column]
        TotalShareValue=TotalShareValue+Portfolio$Volume[i]*Current_Price
    }
    Cash<<-Cash+TotalShareValue
    StockValue<<-0
    MTM<<-StockValue+Cash
    
}

# %%
#Function to Calculate the Divident
DividentCalculator= function(name,i)
    {
    close = paste0(name, ".Close")
    AdjClose = paste0(name, ".Adj.Close")
    
    (((StockData[i-1,close]/StockData[i,close]) - (StockData[i-1,AdjClose]/StockData[i,AdjClose]))*  StockData[i,close]  )

}

# %%
#Function to Update Divident and add the divident to Cash
UpdateDivident<-function(Current_Row)
    {
    for(i in (Current_Row-(DaysIncrementor-1)):Current_Row)
        {
        for(j in 1:length(Portfolio$PurchaseDate))
            {
            
            name=Portfolio$Company[j]
            Divident= DividentCalculator(name,i )
            if(Divident>0.1)
                {
                #The Printable lines here can be uncommented 
                #The print lines will show up if Divident occurs, while running the portfolio function
                
                #print("--------------------------------------------------------------------------------")
                DividentAmount=Divident* Portfolio$Volume[j]
                #print(paste("name= ",name))
                #print(paste("Cash Before= ",Cash))
                #print(paste("DividentAAmount= ",DividentAmount))
                Cash<<-Cash+DividentAmount
                #print(paste("Cash After= ",Cash))
                #print("--------------------------------------------------------------------------------")
            }
            #StockData
        }
    }
}

# %%
#This function helps in finding Daily MTM
DailyMTMCalculator<- function(index,DaysIncrementor)
    {
    
    StockValueT=c((1:(DaysIncrementor-1)*0))
    for(i in 1:length(Portfolio$PurchaseDate))
        {
        
        col_name= paste0(Portfolio$Company[i], ".Close")
        
        for(j in 1:(DaysIncrementor-1))
            {
            StockValueT[j]= StockValueT[j] + StockData[index-DaysIncrementor+j,col_name]*Portfolio$Volume[i]
        }
        
    }
    for(j in 1:(DaysIncrementor-1))
        {
        MTMT[index-DaysIncrementor+j]<<-StockValueT[j]+Cash
    }
    
    for(j in 1:(DaysIncrementor-1))
        {
        MTMPCT[index-DaysIncrementor+j]<<-PercentageChange(MTMT[index-DaysIncrementor+j-1],MTMT[index-DaysIncrementor+j])
    }
    
    
}

# %%
#Main function to run run all the functions of portfolio. The Current_Row Paramenter keeps changing with the incrementor
#DaysIncrementor refers to number of days for rebalancing,BuyStrategy refers to high or low buy strategy 
PortfolioRunner <- function(Current_Row,DaysIncrementor,BuyStrategy)
{
    
    DateToBuy=StockData$Date[Current_Row]
    
    if(DateToBuy=="2018-01-02")
        {
        
        MTMPCT[Current_Row]<<-0
        
        buy(DateToBuy)  
        MTMT[Current_Row]<<-MTM
    }
     else{
         #
         UpdateDivident(Current_Row)
         
         #Find5MostDroppedAdjacentClose and Updates the catalog
         UpdateBuyCatalog(Current_Row,BuyStrategy,DaysIncrementor)
         if(DaysIncrementor>1)
            {
             DailyMTMCalculator(Current_Row,DaysIncrementor)
             }
         
         SellAllShares(Current_Row)
         #empties the portfolio
         Portfolio<<-Portfolio[0,]
         #for next purchase
         CashEachShare<<-Cash/5;
         #buy again
         buy(DateToBuy) 
         
         MTMT[Current_Row]<<-MTM
         MTMPCT[Current_Row]<<-PercentageChange(MTMT[Current_Row-1],MTMT[Current_Row])
     }
    
    Current_Row<<-Current_Row+DaysIncrementor
}

# %%
#Function to calculate HighTechIndex Percent Change
HighTechIndexCalculator<- function()
    {
    HighTechIndexT=c()
    share = c("IBM", "MSFT", "GOOG", "AAPL", "AMZN", "FB", "NFLX", "TSLA", "ORCL", "SAP");
    TotalShare=length(share)
    for(j in 1:length(StockData$Date))
        {
        SumOfTodayShareValue=0
        for(i in 1:length(share))
            {
                curr_column = paste0( share[i], ".Close")
                Current_Share_Price= StockData[j, curr_column]
                SumOfTodayShareValue=SumOfTodayShareValue+Current_Share_Price
            }
        DateT[j]<<- StockData$Date[j]
        HighTechIndexT[j]=SumOfTodayShareValue/TotalShare
        if(j==1)
            {
            HighTechIndexPCT[j]<<-0
        }
        else
            {
            HighTechIndexPCT[j]<<- PercentageChange(HighTechIndexT[j-1],HighTechIndexT[j])
            }
        }
}

# %%
reset()
DaysIncrementor=5
repeat
{
    
    PortfolioRunner(Current_Row,DaysIncrementor,"buying_low")
    print(Portfolio)
    print(paste("Cash= ",Cash))
    print(paste("StockValue= ",StockValue))
    print(paste("MTM= ",MTM))
    
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    if(Current_Row>length(StockData$Date))
        {
        break
    }
}
print(paste0("The MTM at the end of year with ","buying_low strategy = ",MTM))
# Out:
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-02     IBM   6482        154.25
# 2   2018-01-02    MSFT  11634         85.95
# 3   2018-01-02    GOOG    938       1065.00
# 4   2018-01-02    AAPL   5805        172.26
# 5   2018-01-02    AMZN    841       1189.01
# [1] "Cash=  1312.54551699944"
# [1] "StockValue=  4998687.454483"
# [1] "MTM=  5e+06"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-09    AAPL   5957        174.33
# 2   2018-01-09     SAP   9097        114.16
# 3   2018-01-09    MSFT  11772         88.22
# 4   2018-01-09      FB   5528        187.87
# 5   2018-01-09    GOOG    938       1106.26
# [1] "Cash=  1047.86808199994"
# [1] "StockValue=  5191740.451814"
# [1] "MTM=  5192788.319896"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-17      FB   5837        177.60
# 2   2018-01-17     SAP   9324        111.19
# 3   2018-01-17    MSFT  11502         90.14
# 4   2018-01-17    GOOG    915       1131.98
# 5   2018-01-17    ORCL  20625         50.27
# [1] "Cash=  1382.66078599915"
# [1] "StockValue=  5182757.513868"
# [1] "MTM=  5184140.174654"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-24    AAPL   6129        174.22
# 2   2018-01-24     IBM   6457        165.37
# 3   2018-01-24    TSLA   3087        345.89
# 4   2018-01-24    MSFT  11629         91.82
# 5   2018-01-24    ORCL  20754         51.45
# [1] "Cash=  291.416840999387"
# [1] "StockValue=  5338919.020903"
# [1] "MTM=  5339210.437744"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-31    AAPL   6394        167.43
# 2   2018-01-31     IBM   6539        163.70
# 3   2018-01-31     SAP   9453        113.25
# 4   2018-01-31      FB   5728        186.89
# 5   2018-01-31    ORCL  20751         51.59
# [1] "Cash=  221.951754000038"
# [1] "StockValue=  5352583.909897"
# [1] "MTM=  5352805.861651"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-02-07    GOOG    966       1048.58
# 2   2018-02-07     SAP   9641        105.09
# 3   2018-02-07     IBM   6585        153.85
# 4   2018-02-07    MSFT  11306         89.61
# 5   2018-02-07    ORCL  20732         48.87
# [1] "Cash=  427.268554999493"
# [1] "StockValue=  5065506.669016"
# [1] "MTM=  5065933.937571"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-02-14    TSLA   3185        322.31
# 2   2018-02-14      FB   5718        179.52
# 3   2018-02-14     SAP   9764        105.13
# 4   2018-02-14    NFLX   3859        266.00
# 5   2018-02-14    ORCL  20760         49.45
# [1] "Cash=  313.565192709677"
# [1] "StockValue=  5132618.03797"
# [1] "MTM=  5132931.60316271"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-02

# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-11-14    NFLX   3882        286.73
# 2   2018-11-14    AAPL   5959        186.80
# 3   2018-11-14    AMZN    696       1599.01
# 4   2018-11-14    MSFT  10605        104.97
# 5   2018-11-14     SAP  10722        103.83
# [1] "Cash=  788.715149026364"
# [1] "StockValue=  5565610.229588"
# [1] "MTM=  5566398.94473703"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-11-21    NFLX   4050        262.13
# 2   2018-11-21      FB   7876        134.82
# 3   2018-11-21    AAPL   6006        176.78
# 4   2018-11-21    AMZN    700       1516.73
# 5   2018-11-21     SAP  10460        101.51
# [1] "Cash=  610.100433025509"
# [1] "StockValue=  5308715.176296"
# [1] "MTM=  5309325.27672903"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-11-29    ORCL  23381         47.90
# 2   2018-11-29    TSLA   3282        341.17
# 3   2018-11-29    AAPL   6237        179.55
# 4   2018-11-29     SAP  10770        103.99
# 5   2018-11-29     IBM   9219        121.48
# [1] "Cash=  483.160343025811"
# [1] "StockValue=  5599419.724256"
# [1] "MTM=  5599902.88459903"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-12-07    NFLX   4138        265.14
# 2   2018-12-07    AAPL   6512        168.49
# 3   2018-12-07    MSFT  10468        104.82
# 4   2018-12-07    GOOG   1058       1036.58
# 5   2018-12-07    ORCL  23855         46.00
# [1] "Cash=  1045.05062602554"
# [1] "StockValue=  5485643.648078"
# [1] "MTM=  5486688.69870403"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-12-14    AMZN    691       1591.91
# 2   2018-12-14    AAPL   6655        165.48
# 3   2018-12-14     SAP  10905        100.99
# 4   2018-12-14     IBM   9185        119.90
# 5   2018-12-14    GOOG   1056       1042.10
# [1] "Cash=  2627.21636602562"
# [1] "StockValue=  5504314.22809"
# [1] "MTM=  5506941.44445603"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-12-21    AMZN    734       1377.45
# 2   2018-12-21      FB   8098        124.95
# 3   2018-12-21    TSLA   3164        319.77
# 4   2018-12-21    AAPL   6713        150.73
# 5   2018-12-21    NFLX   4106        246.39
# [1] "Cash=  1164.69614202622"
# [1] "StockValue=  5058173.383978"
# [1] "MTM=  5059338.08012003"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-12-31     IBM   9459        113.67
# 2   2018-12-31    ORCL  23814         45.15
# 3   2018-12-31    MSFT  10585        101.57
# 4   2018-12-31     SAP  10800         99.55
# 5   2018-12-31    TSLA   3230        332.80
# [1] "Cash=  468.132135026157"
# [1] "StockValue=  5375609.10235"
# [1] "MTM=  5376077.23448503"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
# [1] "The MTM at the end of year with buying_low strategy = 5376077.23448503"

# %%
#dataframe to store HighTechIndex
HighTech<-data.frame(matrix(ncol = 3),stringsAsFactors = FALSE)
X <- c("Date","HighTechIndexPC","MTMPC")
colnames(Portfolio) <- X

#temporary vectors
DateT=c();
HighTechIndexPCT=c();


HighTechIndexCalculator()


HighTech<<-cbind.data.frame(Date=DateT,HighTechIndexPC=HighTechIndexPCT,MTMPC = MTMPCT,stringsAsFactors = FALSE)

# %%
MTMinYen=MTMT*Yen$Close
MTMinYenPC=c()
MTMinYenPC[1]=0
for(i in 2:length(MTMinYen))
    {
    MTMinYenPC[i]= PercentageChange(MTMinYen[i-1],MTMinYen[i])
    }
YenDollar_MTM<<-cbind.data.frame(Date=DateT,YenMTMPC=MTMinYenPC,MTMPC = MTMPCT,stringsAsFactors = FALSE)

# %%
reset()
repeat
{
    PortfolioRunner(Current_Row,DaysIncrementor,"buying_high")
    print(Portfolio)
    print(paste("Cash= ",Cash))
    print(paste("StockValue= ",StockValue))
    print(paste("MTM= ",MTM))
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    if(Current_Row>length(StockData$Date))
        {
        break
    }
}


print(paste0("The MTM at the end of year with ","buying_high strategy = ",MTM))
# Out:
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-02     IBM   6482        154.25
# 2   2018-01-02    MSFT  11634         85.95
# 3   2018-01-02    GOOG    938       1065.00
# 4   2018-01-02    AAPL   5805        172.26
# 5   2018-01-02    AMZN    841       1189.01
# [1] "Cash=  1312.54551699944"
# [1] "StockValue=  4998687.454483"
# [1] "MTM=  5e+06"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-09     IBM   6339        163.83
# 2   2018-01-09    ORCL  21169         49.06
# 3   2018-01-09    AMZN    829       1252.70
# 4   2018-01-09    TSLA   3112        333.69
# 5   2018-01-09    NFLX   4961        209.31
# [1] "Cash=  400.330367999151"
# [1] "StockValue=  5192387.989528"
# [1] "MTM=  5192788.319896"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-17    TSLA   3091        347.16
# 2   2018-01-17    NFLX   4934        217.50
# 3   2018-01-17    AMZN    828       1295.00
# 4   2018-01-17     IBM   6364        168.65
# 5   2018-01-17    AAPL   5992        179.10
# [1] "Cash=  1640.33464999869"
# [1] "StockValue=  5364932.370132"
# [1] "MTM=  5366572.704782"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-24    NFLX   4271        261.30
# 2   2018-01-24      FB   5982        186.55
# 3   2018-01-24    AMZN    822       1357.51
# 4   2018-01-24     SAP   9758        114.37
# 5   2018-01-24    GOOG    958       1164.24
# [1] "Cash=  1207.69965099823"
# [1] "StockValue=  5579191.994608"
# [1] "MTM=  5580399.694259"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-01-31    AMZN    784       1450.89
# 2   2018-01-31    MSFT  11982         95.01
# 3   2018-01-31    NFLX   4211        270.30
# 4   2018-01-31    TSLA   3213        354.31
# 5   2018-01-31    GOOG    973       1169.94
# [1] "Cash=  1272.02686599828"
# [1] "StockValue=  5690890.451359"
# [1] "MTM=  5692162.478225"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-02-07    NFLX   4103        264.56
# 2   2018-02-07    AMZN    766       1416.78
# 3   2018-02-07    TSLA   3146        345.00
# 4   2018-02-07      FB   6025        180.18
# 5   2018-02-07    AAPL   6805        159.54
# [1] "Cash=  1182.76615199819"
# [1] "StockValue=  5427367.284198"
# [1] "MTM=  5428550.05035"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-02-14    AAPL   6504        167.37
# 2   2018-02-14    AMZN    750       1451.05
# 3   2018-02-14    GOOG   1017       1069.70
# 4   2018-02-14    MSFT  11987         90.81
# 5   2018-02-14     IBM   7034        154.76
# [1] "Cash=  1052.19503949955"
# [1] "StockValue=  5441868.085253"
# [1] "MTM=  5442920.2802925"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-02-22    TSLA   3200        346.17
# 2   2018-02-22    NFLX   3983        278.14
# 3   2018-02-22    GOOG   1001       1106.63
# 4   2018-02-22    AAPL   6422        172.50
# 5   2018-02-22    AMZN    745       1485.34
# [1] "Cash=  1789.8703274997"
# [1] "StockValue=  5537685.63102"
# [1] "MTM=  5539475.5013475"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-03

# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-11-21    ORCL  21397         48.62
# 2   2018-11-21    GOOG   1002       1037.61
# 3   2018-11-21     IBM   8774        118.57
# 4   2018-11-21    TSLA   3076        338.19
# 5   2018-11-21    MSFT  10089        103.11
# [1] "Cash=  781.676935534924"
# [1] "StockValue=  5200889.749814"
# [1] "MTM=  5201671.42674953"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-11-29    AMZN    638       1673.57
# 2   2018-11-29    NFLX   3700        288.75
# 3   2018-11-29    MSFT   9698        110.19
# 4   2018-11-29    GOOG    981       1088.30
# 5   2018-11-29      FB   7705        138.68
# [1] "Cash=  2299.14623753447"
# [1] "StockValue=  5340886.959078"
# [1] "MTM=  5343186.10531553"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-12-07    TSLA   2857        357.97
# 2   2018-12-07      FB   7444        137.42
# 3   2018-12-07     IBM   8572        119.34
# 4   2018-12-07    AMZN    627       1629.13
# 5   2018-12-07     SAP  10156        100.72
# [1] "Cash=  1918.47938153427"
# [1] "StockValue=  5113034.046972"
# [1] "MTM=  5114952.52635353"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-12-14      FB   7178        144.06
# 2   2018-12-14    TSLA   2827        365.71
# 3   2018-12-14    ORCL  22191         46.60
# 4   2018-12-14    MSFT   9753        106.03
# 5   2018-12-14    NFLX   3875        266.84
# [1] "Cash=  558.446364535019"
# [1] "StockValue=  5170140.930566"
# [1] "MTM=  5170699.37693053"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-12-21     SAP   9757         96.14
# 2   2018-12-21    ORCL  21321         44.00
# 3   2018-12-21    GOOG    957        979.54
# 4   2018-12-21    MSFT   9550         98.23
# 5   2018-12-21     IBM   8456        110.94
# [1] "Cash=  854.834366534837"
# [1] "StockValue=  4689786.914751"
# [1] "MTM=  4690641.74911753"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
#   PurchaseDate Company Volume PurchasePrice
# 1   2018-12-31    AMZN    646       1501.97
# 2   2018-12-31    NFLX   3629        267.66
# 3   2018-12-31    GOOG    938       1035.61
# 4   2018-12-31      FB   7410        131.09
# 5   2018-12-31    AAPL   6158        157.74
# [1] "Cash=  1320.42215053458"
# [1] "StockValue=  4855752.742862"
# [1] "MTM=  4857073.16501253"
# [1] "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
# [1] "The MTM at the end of year with buying_high strategy = 4857073.16501253"

# %%
#Graph of HighTechIndex and MTM percent change on date 
data.frame(Date=HighTech$Date,HTINDEX=HighTech$HighTechIndexPC,MTM=HighTech$MTMPC)%>%
reshape2::melt(id.vars = "Date")%>%
ggplot(aes(x=Date,y=value, group = variable, colour = variable))+geom_line(size = 1)
# Out:
# plot without title

# %%
#Graph of MTM percent change in Dollar and Yen on each date 
data.frame(Date=YenDollar_MTM$Date,YenMTMPC=YenDollar_MTM$YenMTMPC,DollarMTMPC=YenDollar_MTM$MTMPC)%>%
reshape2::melt(id.vars = "Date")%>%
ggplot(aes(x=Date,y=value, group = variable, colour = variable))+geom_line(size = 1)
# Out:
# plot without title

# %%
MTMAllInterval=c()
Optimal_interval=0
max=0
for(i in 1:250)
    {
    reset()
    DaysIncrementor<<-i
    repeat
    {
        PortfolioRunner(Current_Row,DaysIncrementor,"buying_low")
        MTMAllInterval[i]=MTM
        if(Current_Row>length(StockData$Date))
            {
            break
        }
    }

    print(paste0("For days interval= ",i," The MTM is= ",MTM))
}
# Out:
# [1] "For days interval= 1 The MTM is= 4851851.3022866"
# [1] "For days interval= 2 The MTM is= 5181958.27231583"
# [1] "For days interval= 3 The MTM is= 4954394.65475663"
# [1] "For days interval= 4 The MTM is= 5740964.78837545"
# [1] "For days interval= 5 The MTM is= 5376077.23448503"
# [1] "For days interval= 6 The MTM is= 4511128.99072897"
# [1] "For days interval= 7 The MTM is= 4662535.99360702"
# [1] "For days interval= 8 The MTM is= 5787268.60589359"
# [1] "For days interval= 9 The MTM is= 5386399.66579195"
# [1] "For days interval= 10 The MTM is= 5469838.26745059"
# [1] "For days interval= 11 The MTM is= 4939919.93815336"
# [1] "For days interval= 12 The MTM is= 4864790.56740555"
# [1] "For days interval= 13 The MTM is= 5323714.87679767"
# [1] "For days interval= 14 The MTM is= 5676839.79139241"
# [1] "For days interval= 15 The MTM is= 5760617.53732617"
# [1] "For days interval= 16 The MTM is= 5610182.00960283"
# [1] "For days interval= 17 The MTM is= 5346397.19624363"
# [1] "For days interval= 18 The MTM is= 5532936.5125623"
# [1] "For days interval= 19 The MTM is= 4939457.40179288"
# [1] "For days interval= 20 The MTM is= 5471374.36091581"
# [1] "For days interval= 21 The MTM is= 5841506.06252435"
# [1] "For days interval= 22 The MTM is= 5380044.40893946"
# [1] "For days interval= 23 The MTM is= 5661945.7211495"
# [1] "For days interval= 24 The MTM is= 5628715.21579125"
# [1] "For days interval= 25 The MTM is= 5271420.79959547"
# [1] "For days interval= 26 The MTM is= 5821399.68536373"
# [1] "For days interval= 27 The MTM is= 5155865.06989408"
# [1] "For days interval= 28 The MTM is= 5410414.87924194"
# [1] "For days interval= 29 The MTM is= 5166695.88996239"
# [1] "For days interval= 30 The MTM is= 5202081.16799517"
# [1] "For days interval= 31 The MTM is= 5261644.79710167"
# [1] "For days interval= 32 The MTM is= 5179417.269067"
# [1] "For days interval= 33 The MTM is= 5784291.22362722"
# [1] "For days interval= 34 The MTM is= 5712835.28398014"
# [1] "For days interval= 35 The MTM is= 5300218.6429583"
# [1] "For days interval= 36 The MTM is= 5922932.50940251"
# [1] "For days interval= 37 The MTM is= 5794811.30468667"
# [1] "For days interval= 38 The MTM is= 5697016.1096673"
# [1] "For days interval= 39 The MTM is= 6161832.31709846"
# [1] "For days interval= 40 The MTM is= 5667601.57526441"
# [1] "For days interval= 41 The MTM is= 4512708.74663635"
# [1] "For days interval= 42 The MTM is= 5617652.02960614"
# [1] "For days interval= 43 The MTM is= 5879641.5935684"
# [1] "For days interval= 44 The MTM is= 5523448.14076326"
# [1] "For days interval= 45 The MTM is= 5321506.33293804"
# [1] "For days interval= 46 The MTM is= 5742847.97042553"
# [1] "For days interval= 47 The MTM is= 5883153.53328534"
# [1] "For days interval= 48 The MTM is= 6047807.16116408"
# [1] "For days interval= 49 The MTM is= 5272257.27390044"
# [1] "For days interval= 50 The MTM is= 5479404.2722329"
# [1] "For days interval= 51 The MTM is= 5565251.35649301"
# [1] "For days interval= 52 The MTM is= 5381331.05345496"
# [1] "For days interval= 53 The MTM is= 5601517.96007773"
# [1] "For days interval= 54 The MTM is= 5752890.91146906"
# [1] "For days interval= 55 The MTM is= 5725543.26849134"
# [1] "For days interval= 56 The MTM is= 5534008.08983534"
# [1] "For days interval= 57 The MTM is= 6022889.72500552"
# [1] "For days interval= 58 The MTM is= 6546481.35833213"
# [1] "For days interval= 59 The MTM is= 6245447.59796149"
# [1] "For days interval= 60 The MTM is= 6183933.59525515"
# [1] "For days interval= 61 The MTM is= 5762690.4535251"
# [1] "For days interval= 62 The MTM is= 5621421.78093251"
# [1] "For days interval= 63 The MTM is= 6628875.4967289"
# [1] "For days interval= 64 The MTM is= 6178341.87546258"
# [1] "For days interval= 65 The MTM is= 5880871.91632974"
# [1] "For days interval= 66 The MTM is= 5837351.68750254"
# [1] "For days interval= 67 The MTM is= 5844760.94031734"
# [1] "For days interval= 68 The MTM is= 6057359.34234492"
# [1] "For days interval= 69 The MTM is= 5953338.19069743"
# [1] "For days interval= 70 The MTM is= 6006353.5712409"
# [1] "For days interval= 71 The MTM is= 5720601.87486837"
# [1] "For days interval= 72 The MTM is= 5729052.22300419"
# [1] "For days interval= 73 The MTM is= 5401096.44539246"
# [1] "For days interval= 74 The MTM is= 5310476.07188499"
# [1] "For days interval= 75 The MTM is= 5169986.97494269"
# [1] "For days interval= 76 The MTM is= 5123020.91827757"
# [1] "For days interval= 77 The MTM is= 5401040.3275197"
# [1] "For days interval= 78 The MTM is= 5293417.4423904"
# [1] "For days interval= 79 The MTM is= 5476042.59040932"
# [1] "For days interval= 80 The MTM is= 5100411.13948729"
# [1] "For days interval= 81 The MTM is= 5171804.24491354"
# [1] "For days interval= 82 The MTM is= 4822738.07269201"
# [1] "For days interval= 83 The MTM is= 4998060.32844238"
# [1] "For days interval= 84 The MTM is= 5766988.14056648"
# [1] "For days interval= 85 The MTM is= 5579849.04472009"
# [1] "For days interval= 86 The MTM is= 5443588.10440535"
# [1] "For days interval= 87 The MTM is= 5562194.35280677"
# [1] "For days interval= 88 The MTM is= 5562764.76546657"
# [1] "For days interval= 89 The MTM is= 5560608.45634668"
# [1] "For days interval= 90 The MTM is= 5618470.21931116"
# [1] "For days interval= 91 The MTM is= 5718848.51707472"
# [1] "For days interval= 92 The MTM is= 6005771.5776509"
# [1] "For days interval= 93 The MTM is= 5845852.05581466"
# [1] "For days interval= 94 The MTM is= 5821039.26290538"
# [1] "For days interval= 95 The MTM is= 5757733.19247432"
# [1] "For days interval= 96 The MTM is= 5474945.60908691"
# [1] "For days interval= 97 The MTM is= 5492430.1853828"
# [1] "For days interval= 98 The MTM is= 5433258.65254989"
# [1] "For days interval= 99 The MTM is= 5329645.85686509"
# [1] "For days interval= 100 The MTM is= 5398825.74117305"
# [1] "For days interval= 101 The MTM is= 5426765.68756591"
# [1] "For days interval= 102 The MTM is= 5525967.80917545"
# [1] "For days interval= 103 The MTM is= 5578619.54894863"
# [1] "For days interval= 104 The MTM is= 5474502.17593517"
# [1] "For days interval= 105 The MTM is= 5406171.9794624"
# [1] "For days interval= 106 The MTM is= 5499289.34563511"
# [1] "For days interval= 107 The MTM is= 5402019.34730002"
# [1] "For days interval= 108 The MTM is= 5518731.60187467"
# [1] "For days interval= 109 The MTM is= 5284870.00667242"
# [1] "For days interval= 110 The MTM is= 5266322.81504622"
# [1] "For days interval= 111 The MTM is= 5324678.3379869"
# [1] "For days interval= 112 The MTM is= 5110449.73099198"
# [1] "For days interval= 113 The MTM is= 4972513.58783182"
# [1] "For days interval= 114 The MTM is= 4978500.20377482"
# [1] "For days interval= 115 The MTM is= 5096716.55096458"
# [1] "For days interval= 116 The MTM is= 5296747.42328327"
# [1] "For days interval= 117 The MTM is= 5457009.76348304"
# [1] "For days interval= 118 The MTM is= 5528620.21450985"
# [1] "For days interval= 119 The MTM is= 5562342.97993104"
# [1] "For days interval= 120 The MTM is= 5416312.76576288"
# [1] "For days interval= 121 The MTM is= 5270154.77495906"
# [1] "For days interval= 122 The MTM is= 5142194.20176697"
# [1] "For days interval= 123 The MTM is= 4653817.5753932"
# [1] "For days interval= 124 The MTM is= 5167833.56794988"
# [1] "For days interval= 125 The MTM is= 5265206.3162295"
# [1] "For days interval= 126 The MTM is= 5622707.11064277"
# [1] "For days interval= 127 The MTM is= 5676522.07570978"
# [1] "For days interval= 128 The MTM is= 5738615.85259577"
# [1] "For days interval= 129 The MTM is= 5811070.38534777"
# [1] "For days interval= 130 The MTM is= 5817221.71850578"
# [1] "For days interval= 131 The MTM is= 5813772.94010877"
# [1] "For days interval= 132 The MTM is= 5930305.98575777"
# [1] "For days interval= 133 The MTM is= 5961718.24716077"
# [1] "For days interval= 134 The MTM is= 5953681.91335578"
# [1] "For days interval= 135 The MTM is= 5988191.17217477"
# [1] "For days interval= 136 The MTM is= 5975527.78839977"
# [1] "For days interval= 137 The MTM is= 5972782.79443777"
# [1] "For days interval= 138 The MTM is= 5971942.20698877"
# [1] "For days interval= 139 The MTM is= 5997967.26869877"
# [1] "For days interval= 140 The MTM is= 6069686.34996977"
# [1] "For days interval= 141 The MTM is= 6162243.58362177"
# [1] "For days interval= 142 The MTM is= 6102783.81034477"
# [1] "For days interval= 143 The MTM is= 6031167.18541377"
# [1] "For days interval= 144 The MTM is= 5950688.34746877"
# [1] "For days interval= 145 The MTM is= 5953701.08772578"
# [1] "For days interval= 146 The MTM is= 6031005.24545578"
# [1] "For days interval= 147 The MTM is= 6113715.14578277"
# [1] "For days interval= 148 The MTM is= 6141817.43813577"
# [1] "For days interval= 149 The MTM is= 6159874.09871677"
# [1] "For days interval= 150 The MTM is= 6192330.06517677"
# [1] "For days interval= 151 The MTM is= 6222859.20370577"
# [1] "For days interval= 152 The MTM is= 6244216.07764025"
# [1] "For days interval= 153 The MTM is= 6209887.61754257"
# [1] "For days interval= 154 The MTM is= 6202889.39502257"
# [1] "For days interval= 155 The MTM is= 6254288.87302257"
# [1] "For days interval= 156 The MTM is= 6186336.71868923"
# [1] "For days interval= 157 The MTM is= 6209131.68722823"
# [1] "For days interval= 158 The MTM is= 6229026.49765822"
# [1] "For days interval= 159 The MTM is= 6213130.59580323"
# [1] "For days interval= 160 The MTM is= 6196712.36977823"
# [1] "For days interval= 161 The MTM is= 6228023.91218423"
# [1] "For days interval= 162 The MTM is= 6233726.66493622"
# [1] "For days interval= 163 The MTM is= 6268148.90295622"
# [1] "For days interval= 164 The MTM is= 6335259.21278322"
# [1] "For days interval= 165 The MTM is= 6346820.49373823"
# [1] "For days interval= 166 The MTM is= 6464419.77899723"
# [1] "For days interval= 167 The MTM is= 6459120.26014922"
# [1] "For days interval= 168 The MTM is= 6471254.49493922"
# [1] "For days interval= 169 The MTM is= 6465756.06392222"
# [1] "For days interval= 170 The MTM is= 6378545.39617623"
# [1] "For days interval= 171 The MTM is= 6313006.56607223"
# [1] "For days interval= 172 The MTM is= 6278850.34636423"
# [1] "For days interval= 173 The MTM is= 6265356.05701122"
# [1] "For days interval= 174 The MTM is= 6376900.96680123"
# [1] "For days interval= 175 The MTM is= 6355507.91043822"
# [1] "For days interval= 176 The MTM is= 6427519.60154823"
# [1] "For days interval= 177 The MTM is= 6394756.26894423"
# [1] "For days interval= 178 The MTM is= 6275585.96742123"
# [1] "For days interval= 179 The MTM is= 6326762.18514923"
# [1] "For days interval= 180 The MTM is= 6310144.63493623"
# [1] "For days interval= 181 The MTM is= 6384922.67853722"
# [1] "For days interval= 182 The MTM is= 6336364.22861323"
# [1] "For days interval= 183 The MTM is= 6373849.41902523"
# [1] "For days interval= 184 The MTM is= 6416537.68307223"
# [1] "For days interval= 185 The MTM is= 6414646.40692523"
# [1] "For days interval= 186 The MTM is= 6490572.71308623"
# [1] "For days interval= 187 The MTM is= 6483322.93881423"
# [1] "For days interval= 188 The MTM is= 6521045.10205123"
# [1] "For days interval= 189 The MTM is= 6508988.43972722"
# [1] "For days interval= 190 The MTM is= 6509044.91301223"
# [1] "For days interval= 191 The MTM is= 6376237.17607222"
# [1] "For days interval= 192 The MTM is= 6305506.69236823"
# [1] "For days interval= 193 The MTM is= 6254369.30998723"
# [1] "For days interval= 194 The MTM is= 6276755.57730223"
# [1] "For days interval= 195 The MTM is= 5964481.96481823"
# [1] "For days interval= 196 The MTM is= 5894731.23849722"
# [1] "For days interval= 197 The MTM is= 6080732.16752523"
# [1] "For days interval= 198 The MTM is= 5992067.78045323"
# [1] "For days interval= 199 The MTM is= 6162150.01387822"
# [1] "For days interval= 200 The MTM is= 6086102.78397523"
# [1] "For days interval= 201 The MTM is= 5930382.06779023"
# [1] "For days interval= 202 The MTM is= 5944280.45834023"
# [1] "For days interval= 203 The MTM is= 5994968.21601223"
# [1] "For days interval= 204 The MTM is= 5982004.58905023"
# [1] "For days interval= 205 The MTM is= 5706902.11922223"
# [1] "For days interval= 206 The MTM is= 5940180.24593823"
# [1] "For days interval= 207 The MTM is= 5753705.52139523"
# [1] "For days interval= 208 The MTM is= 5524964.21614122"
# [1] "For days interval= 209 The MTM is= 5510252.88241823"
# [1] "For days interval= 210 The MTM is= 5673444.27642222"
# [1] "For days interval= 211 The MTM is= 5742103.68660523"
# [1] "For days interval= 212 The MTM is= 5640358.09803823"
# [1] "For days interval= 213 The MTM is= 5601994.92311623"
# [1] "For days interval= 214 The MTM is= 5664296.81597622"
# [1] "For days interval= 215 The MTM is= 5890662.62739822"
# [1] "For days interval= 216 The MTM is= 5873898.64730178"
# [1] "For days interval= 217 The MTM is= 5775269.38682979"
# [1] "For days interval= 218 The MTM is= 5577577.00737878"
# [1] "For days interval= 219 The MTM is= 5559543.88370278"
# [1] "For days interval= 220 The MTM is= 5486398.53166309"
# [1] "For days interval= 221 The MTM is= 5584998.22010709"
# [1] "For days interval= 222 The MTM is= 5584986.31680109"
# [1] "For days interval= 223 The MTM is= 5382458.36230009"
# [1] "For days interval= 224 The MTM is= 5268144.71403909"
# [1] "For days interval= 225 The MTM is= 5321155.07669709"
# [1] "For days interval= 226 The MTM is= 5260463.94839609"
# [1] "For days interval= 227 The MTM is= 5418779.62970909"
# [1] "For days interval= 228 The MTM is= 5423541.91156309"
# [1] "For days interval= 229 The MTM is= 5648230.90951009"
# [1] "For days interval= 230 The MTM is= 5617916.01243509"
# [1] "For days interval= 231 The MTM is= 5658224.28994409"
# [1] "For days interval= 232 The MTM is= 5795527.31093009"
# [1] "For days interval= 233 The MTM is= 5543158.43503409"
# [1] "For days interval= 234 The MTM is= 5597184.80838009"
# [1] "For days interval= 235 The MTM is= 5391479.15778809"
# [1] "For days interval= 236 The MTM is= 5454545.50095709"
# [1] "For days interval= 237 The MTM is= 5472295.10935509"
# [1] "For days interval= 238 The MTM is= 5510737.09923509"
# [1] "For days interval= 239 The MTM is= 5516984.29560409"
# [1] "For days interval= 240 The MTM is= 5365588.92595009"
# [1] "For days interval= 241 The MTM is= 5211791.26456609"
# [1] "For days interval= 242 The MTM is= 5277419.91358909"
# [1] "For days interval= 243 The MTM is= 5189887.43159709"
# [1] "For days interval= 244 The MTM is= 5077292.30486009"
# [1] "For days interval= 245 The MTM is= 4892099.09455909"
# [1] "For days interval= 246 The MTM is= 4768636.55846509"
# [1] "For days interval= 247 The MTM is= 5094303.80400009"
# [1] "For days interval= 248 The MTM is= 5107446.09775109"
# [1] "For days interval= 249 The MTM is= 5101255.27597009"
# [1] "For days interval= 250 The MTM is= 5146660.55936009"

# %%
BestOptimalDay=order(MTMAllInterval, decreasing = TRUE)

# %%
print("the optimal days interval that maximizes the MTM are following")
head(BestOptimalDay)
# Out:
# [1] "the optimal days interval that maximizes the MTM are following"
# [1]  63  58 188 190 189 186

# %%
rm(list = ls())
